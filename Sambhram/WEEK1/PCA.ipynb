# %%
import numpy as np
import matplotlib.pyplot as plt

x = [np.random.rand() for i in range(1000)]
y = [x[i] + 0.05*np.random.rand() for i in range(1000)]
x = np.array(x)
y = np.array(y)
X = np.ones(1000)
X = np.column_stack([X,x])
m_b = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y) #using MA106..
y_line = X.dot(m_b)

plt.scatter(x,y)
plt.plot(x, y_line, color ='red')

# %%
x = [np.random.rand() for i in range(1000)]
y = [(x[i])**2 + 0.05*np.random.rand() for i in range(1000)]

x = np.array(x)
y = np.array(y)
X = np.ones(1000)
X = np.column_stack([X,x])
m_b = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)
y_line = X.dot(m_b)

plt.scatter(x,y)
plt.plot(x, y_line, color ='red')
